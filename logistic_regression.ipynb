# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
X, y = make_classification(n_samples = 150, n_features = 2, n_informative=2, n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=43, hypercube=True, class_sep=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
np.insert(X,0,1,axis=1)
# Out:
# array([[ 1.        ,  1.44061972, -0.55761399],
#        [ 1.        , -0.95760918,  0.30575212],
#        [ 1.        , -1.15200368,  1.20167778],
#        [ 1.        ,  0.37154737, -1.05329484],
#        [ 1.        , -0.91232605,  1.17224738],
#        [ 1.        ,  1.30336737,  0.28753467],
#        [ 1.        ,  1.79031073, -0.61718609],
#        [ 1.        ,  0.20340262, -1.72484405],
#        [ 1.        ,  1.40718784, -0.02503953],
#        [ 1.        ,  1.2334095 , -0.44491315],
#        [ 1.        , -0.96642162,  0.91064658],
#        [ 1.        , -1.67774264,  3.25073708],
#        [ 1.        ,  1.1810507 , -1.41734189],
#        [ 1.        ,  1.76154081, -0.23233055],
#        [ 1.        ,  0.60659929, -0.18671971],
#        [ 1.        ,  1.78795745, -2.17550205],
#        [ 1.        , -1.24241323,  1.95245416],
#        [ 1.        ,  0.74164889, -0.59564464],
#        [ 1.        , -1.20886135,  1.51978995],
#        [ 1.        ,  0.69000427,  0.05501086],
#        [ 1.        ,  1.58470751, -0.53249715],
#        [ 1.        , -1.04903273,  1.05380322],
#        [ 1.        ,  1.00721855,  1.59987213],
#        [ 1.        , -0.95961634,  0.67474378],
#        [ 1.        ,  0.88708507, -1.27920745],
#        [ 1.        , -1.10197801,  0.97169382],
#        [ 1.        ,  1.49427612, -1.36793692],
#        [ 1.        , -0.92625286,  0.32879393],
#        [ 1.        ,  0.22031304, -2.9309047 ],
#        [ 1.        ,  1.10614929, -1.76427578],
#        [ 1.        , -0.71722255,  0.28247756],
#        [ 1.        ,  0.29979783, -1.86691551],
#        [ 1.        , -1.25239332,  1.82282009],
#        [ 1.        ,  0.6264897 , -0.59349509],
#        [ 1.        ,  0.97215479, -2.31009546],
#        [ 1.        , -0.30307405, -0.66403568],
#        [ 1.        , -1.1887851 ,  1.74480943],
#        [ 1.        , -0.7871949 ,  0.47953073],
#        [ 1.        , -0.98631265,  1.42999715],
#        [ 1.        ,  1.22020198,  1.07404966],
#        [ 1.        ,  1.24811237, -0.11561478],
#        [ 1.        ,  1.14804429, -0.47763054],
#        [ 1.        , -0.91164199,  0.47944085],
#        [ 1.        ,  1.50618389, -2.38955821],
#        [ 1.        ,  1.22720352, -0.6273925 ],
#        [ 1.        ,  0.60146288, -0.77667452],
#        [ 1.        , -0.29559167, -0.23112866],
#        [ 1.        , -0.94353986,  1.05108142],
#        [ 1.        , -0.95525955,  0.6038906 ],
#        [ 1.        , -0.95004015,  0.86138575],
#        [ 1.        , -1.12984932,  0.90938363],
#        [ 1.        ,  1.01561444, -1.06547171],
#        [ 1.        ,  0.34454032,  0.50876241],
#        [ 1.        ,  0.86199919,  0.10809547],
#        [ 1.        ,  1.15014027, -1.88484818],
#        [ 1.        ,  1.29235573, -0.34095348],
#        [ 1.        , -1.36967219,  1.64209728],
#        [ 1.        ,  1.3937077 , -0.10319683],
#        [ 1.        , -1.50213213,  1.95454412],
#        [ 1.        , -0.71327717,  0.02344375],
#        [ 1.        , -1.0098724 ,  0.69224352],
#        [ 1.        , -1.3878537 ,  1.81512666],
#        [ 1.        , -0.92300996,  0.52268712],
#        [ 1.        , -0.5156011 , -0.38057298],
#        [ 1.        , -0.93423236,  0.47952855],
#        [ 1.        ,  2.23988399, -0.01264532],
#        [ 1.        , -1.15622683,  1.57486853],
#        [ 1.        ,  0.94880376, -1.39974831],
#        [ 1.        , -0.87016414,  0.79325508],
#        [ 1.        , -0.74599664,  0.47250571],
#        [ 1.        , -1.15079419,  1.91563039],
#        [ 1.        , -0.72246118, -0.72472144],
#        [ 1.        , -0.99708342,  0.27587526],
#        [ 1.        ,  0.40686394, -2.09484488],
#        [ 1.        ,  1.194198  , -0.346406  ],
#        [ 1.        , -1.0864936 ,  1.27371962],
#        [ 1.        ,  0.21974902, -1.35708922],
#        [ 1.        , -0.69895261,  0.53960349],
#        [ 1.        , -1.15664601,  1.21955286],
#        [ 1.        ,  0.95173372, -0.73542823],
#        [ 1.        , -1.31720432,  1.65099464],
#        [ 1.        ,  0.09048048,  0.35868638],
#        [ 1.        ,  1.34549144, -0.13516476],
#        [ 1.        , -1.32092045,  1.90703288],
#        [ 1.        ,  1.92031419, -2.28253003],
#        [ 1.        ,  0.1206749 , -1.70103784],
#        [ 1.        ,  1.13095739, -0.76459204],
#        [ 1.        , -1.19953517,  1.05817102],
#        [ 1.        , -1.00501201,  1.2468402 ],
#        [ 1.        , -1.30896287,  2.0137358 ],
#        [ 1.        , -0.86842748,  0.72838824],
#        [ 1.        ,  1.26398586, -1.39929681],
#        [ 1.        , -1.10456666,  1.56582407],
#        [ 1.        ,  1.57878853,  0.99357208],
#        [ 1.        , -1.05238498,  1.12504032],
#        [ 1.        ,  0.6383262 , -0.71703036],
#        [ 1.        , -0.83181377,  1.0834424 ],
#        [ 1.        , -1.06448041,  1.28450806],
#        [ 1.        ,  1.4501832 , -2.8424399 ],
#        [ 1.        , -1.21268586,  2.2318092 ],
#        [ 1.        ,  1.72485255, -1.19926663],
#        [ 1.        ,  1.00812553, -2.57519713],
#        [ 1.        , -0.86814191, -0.77384035],
#        [ 1.        ,  2.03231752, -0.25608921],
#        [ 1.        ,  1.26822755,  0.76727314],
#        [ 1.        , -1.37837061,  2.10253387],
#        [ 1.        ,  1.64920363,  0.90915557],
#        [ 1.        , -0.95464315,  1.07045833],
#        [ 1.        ,  1.28929917, -1.86383702],
#        [ 1.        , -0.37303492, -1.03571914],
#        [ 1.        ,  1.89892757, -0.12955778],
#        [ 1.        , -0.77426757,  0.99702907],
#        [ 1.        ,  0.80920149, -1.21393642],
#        [ 1.        , -1.11836723,  1.18217032],
#        [ 1.        ,  1.72547961, -2.50232382],
#        [ 1.        , -0.88793702,  0.52900774],
#        [ 1.        ,  0.53336726, -1.52756301],
#        [ 1.        ,  1.00746841, -1.49826212],
#        [ 1.        , -1.26090533,  1.96572335],
#        [ 1.        , -0.87834833,  0.64440541],
#        [ 1.        , -1.20605145,  1.54167678],
#        [ 1.        , -0.90733526,  0.60907284],
#        [ 1.        , -0.60261392, -0.4859897 ],
#        [ 1.        , -0.70050165,  0.19800177],
#        [ 1.        , -1.10986483,  0.94948944],
#        [ 1.        ,  1.37108066, -0.58963734],
#        [ 1.        , -1.58102245,  2.36378254],
#        [ 1.        ,  2.06355045,  0.0444507 ],
#        [ 1.        , -1.07297091,  1.06314849],
#        [ 1.        ,  1.30617658, -0.21176427],
#        [ 1.        ,  0.82928671, -1.06042632],
#        [ 1.        ,  0.92134041, -2.34015307],
#        [ 1.        ,  0.87367811, -0.44131588],
#        [ 1.        , -0.66110556,  0.47078862],
#        [ 1.        ,  1.34023058, -1.06452398],
#        [ 1.        ,  0.90306002, -0.9707908 ],
#        [ 1.        ,  1.2819434 , -1.34509747],
#        [ 1.        , -0.55402482, -0.4537793 ],
#        [ 1.        , -1.00176956,  1.48560354],
#        [ 1.        , -0.93732279,  1.61096217],
#        [ 1.        ,  1.11489161, -1.53367489],
#        [ 1.        ,  1.39824467, -2.56276795],
#        [ 1.        , -1.21531335,  1.68349546],
#        [ 1.        , -0.68439311,  0.37498858],
#        [ 1.        , -1.44724361,  2.53053443],
#        [ 1.        ,  0.56935765, -2.18744092],
#        [ 1.        , -1.01677062,  0.89406119],
#        [ 1.        ,  0.67897457, -0.01636869],
#        [ 1.        , -0.65115909, -0.33822914],
#        [ 1.        ,  0.84198701,  0.48709156]])

# %%
np.ones(X.shape[1])
# Out:
# array([1., 1.])

# %%
from PIL import Image
percep = Image.open("perceptron.png")

# %%
percep
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x138>

# %%
def step(z):
    return 1 if z>0 else 0

# %%
def perceptron(X, y):
    X = np.insert(X,0,1,axis=1)
    #To input ones to multiply with bias term(intercept)
    weights = np.ones(X.shape[1])
    #X.shape[1] gets the number of columns in the tuple and return that number of ones as weights
    lr = 0.1

    for i in range(900):
        #running it for 1000 epochs
        j = np.random.randint(0,100)
        #chosses random point in dataseet
        y_hat = step(np.dot(X[j],weights))
        #dot product of weights and the row in X
        #step to return 1 if greater than 0 or return 0 if less than 0
        weights = weights + lr*(y[j]-y_hat)*X[j]
        #standard equation
    return weights[0],weights[1:]
    #returning intercept and coeffs

# %%
intercept_,coef_= perceptron(X,y)

# %%
print(intercept_,coef_)
# Out:
# -0.09999999999999992 [-0.62463879 -0.08172812]

# %%
coco = Image.open("coco.png")

# %%
coco
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1156x614>

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
#In range -3 to 3 using 100 points make a line
y_input = m*x_input + b

# %%
plt.figure(figsize=(12,4))
plt.plot(x_input,y_input,color='red',linewidth=2)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-4,4)
plt.xlim(-2,2.5)
# Out:
# (-2.0, 2.5)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
lr.coef_[0]
# Out:
# array([-3.19679275,  0.64371536])

# %%
lr.coef_[0][1]
# Out:
# np.float64(0.6437153628591321)

# %%
m = -(lr.coef_[0][0]/lr.coef_[0][1])
b = -(lr.intercept_/lr.coef_[0][1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input + b

# %%
plt.figure(figsize=(12,4))
plt.plot(x_input,y_input,color='red',linewidth=2)
plt.plot(x_input1,y_input1,color='black',linewidth=2)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-4,4)
plt.xlim(-2,2.5)
# Out:
# (-2.0, 2.5)

# %%
#The above graph shows that this way is not the most perfect one compared to sklearn which is performing better

# %%
# Above was using the step function, now let's try using sigmoid function

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = sigmoid(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
intercept_,coef_ = perceptron(X,y)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input2 = np.linspace(-3,3,100)
y_input2 = m*x_input + b

# %%
plt.figure(figsize=(12,4))
plt.plot(x_input,y_input,color='red',linewidth=2)
plt.plot(x_input1,y_input1,color='black',linewidth=2)
plt.plot(x_input2,y_input2,color='navy',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-4,4)
plt.xlim(-2,2.5)
# Out:
# (-2.0, 2.5)

# %%
#We can see significant improvement in sigmoid compared to step, Still not as good as the sklearn class
