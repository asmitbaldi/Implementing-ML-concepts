# %%
import requests

# %%
url = "https://youtube138.p.rapidapi.com/channel/videos/"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}

# %%
import http.client

conn = http.client.HTTPSConnection("youtube138.p.rapidapi.com")

payload = "{\"id\":\"UCJ5v_MCY6GNUBTO8-D3XoAg\",\"filter\":\"videos_latest\",\"cursor\":\"\",\"hl\":\"en\",\"gl\":\"US\"}"

headers = {
    'x-rapidapi-key': "c02c021e76msh036de48b317c08bp16faedjsncc42c154ff6d",
    'x-rapidapi-host': "youtube138.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("POST", "/channel/videos/", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"contents":[],"cursorNext":"..."}

# %%
import http.client

conn = http.client.HTTPSConnection("fresh-linkedin-profile-data.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "c02c021e76msh036de48b317c08bp16faedjsncc42c154ff6d",
    'x-rapidapi-host': "fresh-linkedin-profile-data.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/get-extra-profile-data?urn=ACoAAABD0a4B2wblfHunfjGEN-uRLdg2MnWydmk&include_publications=true&include_honors=true&include_patents=true&include_courses=true&include_projects=true&include_volunteers=true&include_organizations=true&include_languages=true&include_certifications=true", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"message":"You are not subscribed to this API."}
