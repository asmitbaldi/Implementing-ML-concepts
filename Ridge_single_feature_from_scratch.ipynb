# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=200,n_features=1,n_targets=1,n_informative=1,noise=30,random_state=42)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import Ridge

# %%
r = Ridge(alpha=15)
r.fit(X,y)
print(r.coef_)
print(r.intercept_)
# Out:
# [79.69418901]
# 4.00298031453737

# %%
from PIL import Image
ridge = Image.open("Ridge-m.png")
ridge = ridge.resize((int(ridge.width * 0.6), int(ridge.height * 0.6)))
ridge
# Out:
# <PIL.Image.Image image mode=RGBA size=615x243>

# %%
class MyRidge:

    def __init__(self,alpha=10):
        self.m = None
        self.b = None
        self.alpha = alpha

    def fit(self,X_train,y_train):
        num = 0
        den = 0

        for i in range(X_train.shape[0]):
            num+= (y_train[i]-y_train.mean())*(X_train[i]-X_train.mean())
            den+= (X_train[i]-X_train.mean())*(X_train[i]-X_train.mean())

        self.m=num/(den+self.alpha)
        self.b=y_train.mean() - (self.m * X_train.mean())

    def coef_(self):
        return self.m

    def intercept_(self):
        return self.b

    def predict(self,X_test):
        pass

# %%
r = MyRidge(alpha=15)
r.fit(X,y)

# %%
r.coef_()
# Out:
# array([79.69418901])

# %%
r.intercept_()
# Out:
# array([4.00298031])

# %%
#We have matched the result to sklearn class :)
