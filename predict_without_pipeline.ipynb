# %%
import pickle
import numpy as np

# %%
oe_sex = pickle.load(open('models/oe_sex.pkl','rb'))
oe_em = pickle.load(open('models/oe_em.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
test_input = np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = oe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /Users/asmitbaldi/ML/ML_codes/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_em = oe_em.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_em),axis=1)

# %%
print(oe_em.categories_)
# Out:
# [array(['C', 'Q', 'S'], dtype=object)]

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([1])
